# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x=np.array([2,4,8,10])
y=np.array([40,80,120,160])
plt.plot(x,y)
plt.show()

# %%
x=np.array([3,6,9,12])
y=np.array([30,50,90,70])
plt.plot(x,y)
plt.show()

# %%
x=np.array([2,4,8,10])
y=np.array([40,80,120,160])

x1=np.array([3,6,9,12])
y1=np.array([30,50,90,70])

plt.plot(x,y)
plt.plot(x1,y1)
plt.show()

# %%
x=np.array([3.2,6,9.5,12])
y=np.array([30,50.2,90,70.9])
plt.plot(x,y)
plt.show()

# %%
x=np.array([4,9,6,2])
y=np.array([10,60,20,50])
plt.plot(x,y)
plt.show()

# %%
x=np.array([2,4,8,10])
y=np.array([40,80,120,160])
plt.plot(x,y,"o")
plt.show()

# %%
x=np.array([10,20,30,40])
y=np.array([100,150,120,180])
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.array([10,20,30,40])
y=np.array([100,150,120,180])
plt.plot(x,y,"*")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.array([10,20,30,40])
y=np.array([100,150,120,180])
plt.plot(x,y,"p")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.array([10,20,30,40])
y=np.array([100,150,120,180])
plt.plot(x,y,"s")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.array([10,20,30,40])
y=np.array([100,150,120,180])
plt.plot(x,y,"h")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.array([10,20,30,40])
y=np.array([100,150,120,180])
plt.plot(x,y,"x")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.array([10,20,30,40])
y=np.array([100,150,120,180])
plt.plot(x,y,"X")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.array([4,9,5,7])
y=np.array([40,60,90,70])

x1=np.array([2,4,6,8])
y1=np.array([10,25,35,75])

plt.plot(x,y)
plt.plot(x1,y1)
plt.show()

# %%
x=np.array([2,4,8,10])
y=np.array([40,80,120,160])

x1=np.array([3,6,9,12])
y1=np.array([30,50,90,70])

plt.plot(x,y,"X")
plt.plot(x1,y1,"s")
plt.show()

# %%
x=np.array([2,4,8,10])
y=np.array([40,80,120,160])
plt.plot(x,y,color="g")
plt.show()

# %%
x=np.array([2,4,8,10])
y=np.array([40,80,120,160])
plt.plot(x,y,color="r")
plt.show()

# %%
x=np.array([2,4,8,10])
y=np.array([40,80,120,160])
plt.plot(x,y,color="blue",ms="10",marker="*",mfc="y",mec="r",linewidth="4",linestyle="dashed")
plt.show()

# %%
x=np.array([2,4,8,10])
y=np.array([40,80,120,160])
plt.plot(x,y,color="black",ms="12",marker="*",mfc="y",mec="r",linewidth="4",linestyle="dotted")
plt.show()

# %%
x=np.array([2,4,8,10])
y=np.array([40,80,120,160])

x1=np.array([3,6,9,12])
y1=np.array([30,50,90,70])

plt.plot(x,y,color="r",ms="13",marker="p",mfc="y",mec="g")
plt.plot(x1,y1,color="yellow",ms="10",marker="X",mfc="blue",mec="r")
plt.grid()
plt.show()

# %%
x=np.array([2,4,8,10])
y=np.array([40,80,120,160])

x1=np.array([3,6,9,12])
y1=np.array([30,50,90,70])

plt.plot(x,y,color="r",ms="11",marker="o",mfc="y",mec="black",linewidth="6",linestyle="dotted")
plt.plot(x1,y1,color="yellow",ms="13",marker="p",mfc="blue",mec="r",linewidth="4",linestyle="dashed")
plt.show()

# %%
x=np.array([2,4,8,10])
y=np.array([40,80,120,160])
plt.plot(x,y,color="g")
plt.grid()
plt.show()

# %%
x=np.array([22,27,35,42])
y=np.array([115,142,130,155])
plt.plot(x,y,color="b",ms="16",marker="o",linestyle="dashed",linewidth="4",mfc="y",mec="black")
plt.grid()
plt.show()
