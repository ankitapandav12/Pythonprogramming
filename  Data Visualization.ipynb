# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r"C:\Users\Sushant\Desktop\Ankita\Datasets\HousePrice.csv")
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29451 entries, 0 to 29450
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   POSTED_BY              29451 non-null  object
#  1   UNDER_CONSTRUCTION     29451 non-null  int64
#  2   RERA                   29451 non-null  int64
#  3   BHK_NO.                29451 non-null  int64
#  4   BHK_OR_RK              29451 non-null  object
#  5   SQUARE_FT              29451 non-null  float64
#  6   READY_TO_MOVE          29451 non-null  int64
#  7   RESALE                 29451 non-null  int64
#  8   ADDRESS                29451 non-null  object
#  9   LONGITUDE              29451 non-null  float64
#  10  LATITUDE               29451 non-null  float64
#  11  TARGET(PRICE_IN_LACS)  29451 non-null  float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 2.7+ MB

# %%
dataset.describe()
# Out:
#        UNDER_CONSTRUCTION          RERA       BHK_NO.     SQUARE_FT  \
# count        29451.000000  29451.000000  29451.000000  2.945100e+04
# mean             0.179756      0.317918      2.392279  1.980217e+04
# std              0.383991      0.465675      0.879091  1.901335e+06
# min              0.000000      0.000000      1.000000  3.000000e+00
# 25%              0.000000      0.000000      2.000000  9.000211e+02
# 50%              0.000000      0.000000      2.000000  1.175057e+03
# 75%              0.000000      1.000000      3.000000  1.550688e+03
# max              1.000000      1.000000     20.000000  2.545455e+08
#
#        READY_TO_MOVE        RESALE     LONGITUDE      LATITUDE  \
# count   29451.000000  29451.000000  29451.000000  29451.000000
# mean        0.820244      0.929578     21.300255     76.837695
# std         0.383991      0.255861      6.205306     10.557747
# min         0.000000      0.000000    -37.713008   -121.761248
# ...

# %%
dataset.isnull().any()
# Out:
# POSTED_BY                False
# UNDER_CONSTRUCTION       False
# RERA                     False
# BHK_NO.                  False
# BHK_OR_RK                False
# SQUARE_FT                False
# READY_TO_MOVE            False
# RESALE                   False
# ADDRESS                  False
# LONGITUDE                False
# LATITUDE                 False
# TARGET(PRICE_IN_LACS)    False
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# POSTED_BY                0
# UNDER_CONSTRUCTION       0
# RERA                     0
# BHK_NO.                  0
# BHK_OR_RK                0
# SQUARE_FT                0
# READY_TO_MOVE            0
# RESALE                   0
# ADDRESS                  0
# LONGITUDE                0
# LATITUDE                 0
# TARGET(PRICE_IN_LACS)    0
# dtype: int64

# %%
dataset.head()
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                   0     0        2       BHK  1300.236407
# 1    Dealer                   0     0        2       BHK  1275.000000
# 2     Owner                   0     0        2       BHK   933.159722
# 3     Owner                   0     1        2       BHK   929.921143
# 4    Dealer                   1     0        2       BHK   999.009247
#
#    READY_TO_MOVE  RESALE                      ADDRESS  LONGITUDE   LATITUDE  \
# 0              1       1        Ksfc Layout,Bangalore  12.969910  77.597960
# 1              1       1    Vishweshwara Nagar,Mysore  12.274538  76.644605
# 2              1       1             Jigani,Bangalore  12.778033  77.632191
# 3              1       1  Sector-1 Vaishali,Ghaziabad  28.642300  77.344500
# 4              0       1             New Town,Kolkata  22.592200  88.484911
#
#    TARGET(PRICE_IN_LACS)
# 0                   55.0
# 1                   51.0
# ...

# %%
dataset.tail()
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# 29446              1       1               Shamshabad Road,Agra  27.140626
# 29447              1       1  E3-108, Lake View Recidency,,Vapi  39.945409
# 29448              1       1                  Ajmer Road,Jaipur  26.928785
# 29449              1       1             Sholinganallur,Chennai  12.900150
# 29450              1       1                   Jagatpura,Jaipur  26.832353
#
#         LATITUDE  TARGET(PRICE_IN_LACS)
# ...

# %%
dataset["BHK_OR_RK"].nunique()
# Out:
# 2

# %%
dataset["BHK_OR_RK"].unique()
# Out:
# array(['BHK', 'RK'], dtype=object)

# %%
dataset["BHK_OR_RK"].value_counts()
# Out:
# BHK    29427
# RK        24
# Name: BHK_OR_RK, dtype: int64

# %% [markdown]
# # Q.1. Find the count of how many flats are BHK & RK

# %%
dataset[["BHK_NO.","BHK_OR_RK","ADDRESS"]]
# Out:
#        BHK_NO. BHK_OR_RK                            ADDRESS
# 0            2       BHK              Ksfc Layout,Bangalore
# 1            2       BHK          Vishweshwara Nagar,Mysore
# 2            2       BHK                   Jigani,Bangalore
# 3            2       BHK        Sector-1 Vaishali,Ghaziabad
# 4            2       BHK                   New Town,Kolkata
# ...        ...       ...                                ...
# 29446        3       BHK               Shamshabad Road,Agra
# 29447        2       BHK  E3-108, Lake View Recidency,,Vapi
# 29448        2       BHK                  Ajmer Road,Jaipur
# 29449        2       BHK             Sholinganallur,Chennai
# 29450        2       BHK                   Jagatpura,Jaipur
#
# [29451 rows x 3 columns]

# %%
dataset["BHK_OR_RK"].value_counts()
# Out:
# BHK    29427
# RK        24
# Name: BHK_OR_RK, dtype: int64

# %%
x=np.array(["BHK","RK"])
y=np.array([29427,24])
plt.bar(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("BHK & RK Flats")
plt.show()

# %% [markdown]
# # Q.2. Calculate the 1 BHK flats in area Jigani,Bangalore & 2 BHK flats in area Jagatpura,Jaipur

# %%
data=dataset[["BHK_NO.","BHK_OR_RK","ADDRESS"]]
data
# Out:
#        BHK_NO. BHK_OR_RK                            ADDRESS
# 0            2       BHK              Ksfc Layout,Bangalore
# 1            2       BHK          Vishweshwara Nagar,Mysore
# 2            2       BHK                   Jigani,Bangalore
# 3            2       BHK        Sector-1 Vaishali,Ghaziabad
# 4            2       BHK                   New Town,Kolkata
# ...        ...       ...                                ...
# 29446        3       BHK               Shamshabad Road,Agra
# 29447        2       BHK  E3-108, Lake View Recidency,,Vapi
# 29448        2       BHK                  Ajmer Road,Jaipur
# 29449        2       BHK             Sholinganallur,Chennai
# 29450        2       BHK                   Jagatpura,Jaipur
#
# [29451 rows x 3 columns]

# %%
a=data.loc[(data["BHK_NO."]==1) & (data["BHK_OR_RK"]=="BHK") & (data["ADDRESS"]=="Jigani,Bangalore")]
a
# Out:
#        BHK_NO. BHK_OR_RK           ADDRESS
# 14861        1       BHK  Jigani,Bangalore
# 16166        1       BHK  Jigani,Bangalore

# %%
a["BHK_NO."].count()
# Out:
# 2

# %%
a1=data.loc[(data["BHK_NO."]==2) & (data["BHK_OR_RK"]=="BHK") & (data["ADDRESS"]=="Jagatpura,Jaipur")]
a1
# Out:
#        BHK_NO. BHK_OR_RK           ADDRESS
# 450          2       BHK  Jagatpura,Jaipur
# 2110         2       BHK  Jagatpura,Jaipur
# 2869         2       BHK  Jagatpura,Jaipur
# 3896         2       BHK  Jagatpura,Jaipur
# 3903         2       BHK  Jagatpura,Jaipur
# 4912         2       BHK  Jagatpura,Jaipur
# 4962         2       BHK  Jagatpura,Jaipur
# 5562         2       BHK  Jagatpura,Jaipur
# 5784         2       BHK  Jagatpura,Jaipur
# 6736         2       BHK  Jagatpura,Jaipur
# 7029         2       BHK  Jagatpura,Jaipur
# 7043         2       BHK  Jagatpura,Jaipur
# 7225         2       BHK  Jagatpura,Jaipur
# 7902         2       BHK  Jagatpura,Jaipur
# 8281         2       BHK  Jagatpura,Jaipur
# 8448         2       BHK  Jagatpura,Jaipur
# 9531         2       BHK  Jagatpura,Jaipur
# 9735         2       BHK  Jagatpura,Jaipur
# 9978         2       BHK  Jagatpura,Jaipur
# 10548        2       BHK  Jagatpura,Jaipur
# 10584        2       BHK  Jagatpura,Jaipur
# ...

# %%
a1["BHK_NO."].count()
# Out:
# 56

# %%
a1["BHK_NO."].value_counts()
# Out:
# 2    56
# Name: BHK_NO., dtype: int64

# %%
x=np.array(["BHK","RK"])
y=np.array([2,56]) 
plt.pie(y,labels=x,radius=2,autopct="%0.1f%%")
plt.show()

# %%
# bar

# %%
x=np.array(["BHK","RK"])
y=np.array([2,56]) 
plt.bar(x,y,color="hotpink")
plt.xlabel("Flats")
plt.ylabel("Counts")
plt.show()

# %% [markdown]
# # Q.3.Calculate the 3 BHK flats are posted by owner & 2 BHK flats are posted by dealer

# %%
data_1=dataset[["POSTED_BY","BHK_NO.","BHK_OR_RK"]]
data_1
# Out:
#       POSTED_BY  BHK_NO. BHK_OR_RK
# 0         Owner        2       BHK
# 1        Dealer        2       BHK
# 2         Owner        2       BHK
# 3         Owner        2       BHK
# 4        Dealer        2       BHK
# ...         ...      ...       ...
# 29446     Owner        3       BHK
# 29447     Owner        2       BHK
# 29448    Dealer        2       BHK
# 29449     Owner        2       BHK
# 29450    Dealer        2       BHK
#
# [29451 rows x 3 columns]

# %%
ab=data_1.loc[(data_1["POSTED_BY"]=="Owner") & (data_1["BHK_NO."]==3) & (data_1["BHK_OR_RK"]=="BHK")]

# %%
ab
# Out:
#       POSTED_BY  BHK_NO. BHK_OR_RK
# 5         Owner        3       BHK
# 7         Owner        3       BHK
# 10        Owner        3       BHK
# 16        Owner        3       BHK
# 26        Owner        3       BHK
# ...         ...      ...       ...
# 29420     Owner        3       BHK
# 29430     Owner        3       BHK
# 29434     Owner        3       BHK
# 29441     Owner        3       BHK
# 29446     Owner        3       BHK
#
# [3340 rows x 3 columns]

# %%
data_1["POSTED_BY"].value_counts()
# Out:
# Dealer     18291
# Owner      10538
# Builder      622
# Name: POSTED_BY, dtype: int64

# %%
bc=data_1.loc[(data_1["POSTED_BY"]=="Dealer") & (data_1["BHK_NO."]==2) & (data_1["BHK_OR_RK"]=="BHK")]
bc
# Out:
#       POSTED_BY  BHK_NO. BHK_OR_RK
# 1        Dealer        2       BHK
# 4        Dealer        2       BHK
# 8        Dealer        2       BHK
# 11       Dealer        2       BHK
# 21       Dealer        2       BHK
# ...         ...      ...       ...
# 29421    Dealer        2       BHK
# 29437    Dealer        2       BHK
# 29439    Dealer        2       BHK
# 29448    Dealer        2       BHK
# 29450    Dealer        2       BHK
#
# [7594 rows x 3 columns]

# %%
data_1["POSTED_BY"].value_counts()
# Out:
# Dealer     18291
# Owner      10538
# Builder      622
# Name: POSTED_BY, dtype: int64

# %%
x=np.array(["BHK","RK"])
y=np.array([10538,18291])
plt.bar(x,y,color="purple")
plt.xlabel("Flats")
plt.ylabel("Counts")
plt.title("Graph")
plt.show()

# %% [markdown]
# # Q.4. Find the 1 BHK flats in area New Town,Kolkata & its SQUARE_FT & Find the 3 BHK flats in area Shamshabad Road,Agra & its SQUARE_FT

# %%
data_2=dataset[["BHK_NO.","BHK_OR_RK","ADDRESS","SQUARE_FT"]]

# %%
data_2
# Out:
#        BHK_NO. BHK_OR_RK                            ADDRESS    SQUARE_FT
# 0            2       BHK              Ksfc Layout,Bangalore  1300.236407
# 1            2       BHK          Vishweshwara Nagar,Mysore  1275.000000
# 2            2       BHK                   Jigani,Bangalore   933.159722
# 3            2       BHK        Sector-1 Vaishali,Ghaziabad   929.921143
# 4            2       BHK                   New Town,Kolkata   999.009247
# ...        ...       ...                                ...          ...
# 29446        3       BHK               Shamshabad Road,Agra  2500.000000
# 29447        2       BHK  E3-108, Lake View Recidency,,Vapi   769.230769
# 29448        2       BHK                  Ajmer Road,Jaipur  1022.641509
# 29449        2       BHK             Sholinganallur,Chennai   927.079009
# 29450        2       BHK                   Jagatpura,Jaipur   896.774194
#
# [29451 rows x 4 columns]

# %%
bhk_1=data_2.loc[(data_2["BHK_NO."]==1) & (data_2["BHK_OR_RK"]=="BHK") & (data_2["ADDRESS"]=="New Town,Kolkata")]
bhk_1
# Out:
#        BHK_NO. BHK_OR_RK           ADDRESS   SQUARE_FT
# 5305         1       BHK  New Town,Kolkata  500.000000
# 6968         1       BHK  New Town,Kolkata  511.945393
# 13159        1       BHK  New Town,Kolkata  449.438202
# 20585        1       BHK  New Town,Kolkata  418.367347
# 27250        1       BHK  New Town,Kolkata  450.058072

# %%
bhk_1["BHK_NO."].value_counts()
# Out:
# 1    5
# Name: BHK_NO., dtype: int64

# %%
bhk_3=data_2.loc[(data_2["BHK_NO."]==3) & (data_2["BHK_OR_RK"]=="BHK") & (data_2["ADDRESS"]=="Shamshabad Road,Agra")]
bhk_3
# Out:
#        BHK_NO. BHK_OR_RK               ADDRESS    SQUARE_FT
# 14262        3       BHK  Shamshabad Road,Agra  1299.435028
# 29446        3       BHK  Shamshabad Road,Agra  2500.000000

# %%
bhk_3["BHK_NO."].value_counts()
# Out:
# 3    2
# Name: BHK_NO., dtype: int64

# %%
x=np.array(["BHK","RK"])
y=np.array([5,2])
plt.bar(x,y,color="orange")
plt.xlabel("x-axis",size="15")
plt.ylabel("y-axis",size="15")
plt.title("DATA",size="20",color="blue")
plt.show()

# %% [markdown]
# # Q.5 Find the 2 BHK flats that latitude in between 50-100 & Find the 3 BHK flats that latitute in between 50-100

# %%
data_3=dataset[["BHK_NO.","BHK_OR_RK","LATITUDE"]]

# %%
data_3
# Out:
#        BHK_NO. BHK_OR_RK   LATITUDE
# 0            2       BHK  77.597960
# 1            2       BHK  76.644605
# 2            2       BHK  77.632191
# 3            2       BHK  77.344500
# 4            2       BHK  88.484911
# ...        ...       ...        ...
# 29446        3       BHK  78.043277
# 29447        2       BHK -86.150721
# 29448        2       BHK  75.828002
# 29449        2       BHK  80.227910
# 29450        2       BHK  75.841749
#
# [29451 rows x 3 columns]

# %%
xy=data_3.loc[(data_3["BHK_NO."]==2) & (data_3["BHK_OR_RK"]=="BHK") & (data_3["LATITUDE"]>=50) & (data_3["LATITUDE"]<=100)]

# %%
xy
# Out:
#        BHK_NO. BHK_OR_RK   LATITUDE
# 0            2       BHK  77.597960
# 1            2       BHK  76.644605
# 2            2       BHK  77.632191
# 3            2       BHK  77.344500
# 4            2       BHK  88.484911
# ...        ...       ...        ...
# 29439        2       BHK  70.789479
# 29445        2       BHK  74.500000
# 29448        2       BHK  75.828002
# 29449        2       BHK  80.227910
# 29450        2       BHK  75.841749
#
# [13207 rows x 3 columns]

# %%
xy["BHK_NO."].value_counts()
# Out:
# 2    13207
# Name: BHK_NO., dtype: int64

# %%
xy["LATITUDE"].max()
# Out:
# 95.0

# %%
xy["LATITUDE"].min()
# Out:
# 69.60929

# %%
yz=data_3.loc[(data_3["BHK_NO."]==3) & (data_3["BHK_OR_RK"]=="BHK") & (data_3["LATITUDE"]>=50) & (data_3["LATITUDE"]<=100)]
yz
# Out:
#        BHK_NO. BHK_OR_RK   LATITUDE
# 5            3       BHK  76.282571
# 6            3       BHK  75.795600
# 7            3       BHK  76.650000
# 10           3       BHK  88.326357
# 15           3       BHK  77.481711
# ...        ...       ...        ...
# 29440        3       BHK  76.841908
# 29441        3       BHK  77.289381
# 29442        3       BHK  77.004317
# 29443        3       BHK  72.878724
# 29446        3       BHK  78.043277
#
# [10442 rows x 3 columns]

# %%
yz["BHK_NO."].value_counts()
# Out:
# 3    10442
# Name: BHK_NO., dtype: int64

# %%
x=np.array(["BHK","RK"])
y=np.array([13207,10442])
plt.pie(y,labels=x,radius=2,autopct="%0.1f%%")
plt.show()

# %% [markdown]
# # Q.6 Find the 1 BHK flats that LONGITUDE in between 20-50  & Find the 2 BHK flats that LONGITUDE in between 20-50

# %%
data_4=dataset[["BHK_NO.","BHK_OR_RK","LONGITUDE"]]
data_4
# Out:
#        BHK_NO. BHK_OR_RK  LONGITUDE
# 0            2       BHK  12.969910
# 1            2       BHK  12.274538
# 2            2       BHK  12.778033
# 3            2       BHK  28.642300
# 4            2       BHK  22.592200
# ...        ...       ...        ...
# 29446        3       BHK  27.140626
# 29447        2       BHK  39.945409
# 29448        2       BHK  26.928785
# 29449        2       BHK  12.900150
# 29450        2       BHK  26.832353
#
# [29451 rows x 3 columns]

# %%
xy1=data_4.loc[(data_4["BHK_NO."]==1) & (data_4["BHK_OR_RK"]=="BHK") & (data_4["LONGITUDE"]>=20) & (data_4["LONGITUDE"]<=50)]
xy1
# Out:
#        BHK_NO. BHK_OR_RK  LONGITUDE
# 40           1       BHK  24.690280
# 48           1       BHK  24.690280
# 138          1       BHK  28.568846
# 230          1       BHK  24.690280
# 267          1       BHK  28.689982
# ...        ...       ...        ...
# 29298        1       BHK  24.690200
# 29307        1       BHK  22.569754
# 29321        1       BHK  30.662283
# 29325        1       BHK  28.629811
# 29416        1       BHK  28.939024
#
# [1447 rows x 3 columns]

# %%
xy1["BHK_NO."].value_counts()
# Out:
# 1    1447
# Name: BHK_NO., dtype: int64

# %%
yz1=data_4.loc[(data_4["BHK_NO."]==2) & (data_4["BHK_OR_RK"]=="BHK") & (data_4["LONGITUDE"]>=20) & (data_4["LONGITUDE"]<=50)]
yz1
# Out:
#        BHK_NO. BHK_OR_RK  LONGITUDE
# 3            2       BHK  28.642300
# 4            2       BHK  22.592200
# 13           2       BHK  28.587711
# 18           2       BHK  21.153890
# 24           2       BHK  21.105779
# ...        ...       ...        ...
# 29437        2       BHK  22.541110
# 29439        2       BHK  22.281215
# 29447        2       BHK  39.945409
# 29448        2       BHK  26.928785
# 29450        2       BHK  26.832353
#
# [6471 rows x 3 columns]

# %%
yz1["BHK_NO."].value_counts()
# Out:
# 2    6471
# Name: BHK_NO., dtype: int64

# %%
x=np.array(["BHK","RK"])
y=np.array([1447,6471])
plt.bar(x,y,color="gray")
plt.title("GRAPH",style="italic",size="20",color="b")
plt.xlabel("x-axis",color="red",size="15")
plt.ylabel("y-axis",color="red",size="15")
plt.grid()
plt.show()

# %% [markdown]
# # Q.7. Find the count of how many flats are ready to move or not

# %%
data_5=dataset[["BHK_NO.","BHK_OR_RK","READY_TO_MOVE"]]
data_5
# Out:
#        BHK_NO. BHK_OR_RK  READY_TO_MOVE
# 0            2       BHK              1
# 1            2       BHK              1
# 2            2       BHK              1
# 3            2       BHK              1
# 4            2       BHK              0
# ...        ...       ...            ...
# 29446        3       BHK              1
# 29447        2       BHK              1
# 29448        2       BHK              1
# 29449        2       BHK              1
# 29450        2       BHK              1
#
# [29451 rows x 3 columns]

# %%
dataset["READY_TO_MOVE"].value_counts()
# Out:
# 1    24157
# 0     5294
# Name: READY_TO_MOVE, dtype: int64

# %%
x=np.array(["BHK","RK"])
y=np.array([24157,5294])
plt.pie(y,labels=x,radius=2,autopct="%0.1f%%")
plt.show()

# %% [markdown]
# # Q.8. Find the count of how many flats are resale or not

# %%
data_6=dataset[["BHK_NO.","BHK_OR_RK","RESALE"]]

# %%
data_6
# Out:
#        BHK_NO. BHK_OR_RK  RESALE
# 0            2       BHK       1
# 1            2       BHK       1
# 2            2       BHK       1
# 3            2       BHK       1
# 4            2       BHK       1
# ...        ...       ...     ...
# 29446        3       BHK       1
# 29447        2       BHK       1
# 29448        2       BHK       1
# 29449        2       BHK       1
# 29450        2       BHK       1
#
# [29451 rows x 3 columns]

# %%
dataset["RESALE"].value_counts()
# Out:
# 1    27377
# 0     2074
# Name: RESALE, dtype: int64

# %%
x=np.array(["BHK","RK"])
y=np.array([27377,2074])
plt.bar(x,y,color="g")
plt.xlabel("x-axis",size="11",color="r")
plt.ylabel("y-axis",size="11",color="r")
plt.grid()
plt.show()
