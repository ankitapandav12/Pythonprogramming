# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv(r"C:\Users\Sushant\Desktop\diabetes_dataset.csv")

# %%
dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
dataset.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
dataset.isnull().any()
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
dataset.count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
dataset.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
dataset["Age"].unique()
# Out:
# array([50, 31, 32, 21, 33, 30, 26, 29, 53, 54, 34, 57, 59, 51, 27, 41, 43,
#        22, 38, 60, 28, 45, 35, 46, 56, 37, 48, 40, 25, 24, 58, 42, 44, 39,
#        36, 23, 61, 69, 62, 55, 65, 47, 52, 66, 49, 63, 67, 72, 81, 64, 70,
#        68], dtype=int64)

# %% [markdown]
# # Q1.You have to find (sum/count) How many peoples have a blood pressure

# %%
dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
a=dataset.loc[(dataset["Outcome"]==0),"Outcome"]
a
# Out:
# 1      0
# 3      0
# 5      0
# 7      0
# 10     0
#       ..
# 762    0
# 763    0
# 764    0
# 765    0
# 767    0
# Name: Outcome, Length: 500, dtype: int64

# %%
a.value_counts()
# Out:
# 0    500
# Name: Outcome, dtype: int64

# %% [markdown]
# # Q2.You have to find (sum/count) How many peoples don't have a blood pressure

# %%
dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
b=dataset.loc[(dataset["Outcome"]==1),"Outcome"]
b
# Out:
# 0      1
# 2      1
# 4      1
# 6      1
# 8      1
#       ..
# 755    1
# 757    1
# 759    1
# 761    1
# 766    1
# Name: Outcome, Length: 268, dtype: int64

# %%
b.value_counts()
# Out:
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# # Q3. Calculate highest rate of glucose between age 30 to 60

# %%
dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
ab = dataset[["Glucose","Age"]]
ab
# Out:
#      Glucose  Age
# 0        148   50
# 1         85   31
# 2        183   32
# 3         89   21
# 4        137   33
# ..       ...  ...
# 763      101   63
# 764      122   27
# 765      121   30
# 766      126   47
# 767       93   23
#
# [768 rows x 2 columns]

# %%
ab1 = ab.loc[(dataset["Age"]>=30) & (dataset["Age"]<=60)]
ab1
# Out:
#      Glucose  Age
# 0        148   50
# 1         85   31
# 2        183   32
# 4        137   33
# 5        116   30
# ..       ...  ...
# 757      123   52
# 761      170   43
# 762       89   33
# 765      121   30
# 766      126   47
#
# [345 rows x 2 columns]

# %%
ab1["Glucose"].max()
# Out:
# 197

# %% [markdown]
# # Q.4 Calculate highest rate of insulin

# %%
dataset["Insulin"]
# Out:
# 0        0
# 1        0
# 2        0
# 3       94
# 4      168
#       ...
# 763    180
# 764      0
# 765    112
# 766      0
# 767      0
# Name: Insulin, Length: 768, dtype: int64

# %%
i=dataset.loc[(dataset["Insulin"]>=126),"Insulin"]

# %%
i
# Out:
# 4      168
# 8      543
# 13     846
# 14     175
# 16     230
#       ...
# 740    150
# 744    140
# 748    200
# 753    510
# 763    180
# Name: Insulin, Length: 196, dtype: int64

# %%
i.count()
# Out:
# 196

# %%
i.max()
# Out:
# 846

# %%
i.unique()
# Out:
# array([168, 543, 846, 175, 230, 235, 146, 140, 245, 192, 207, 240, 300,
#        342, 304, 142, 128, 270, 176, 228, 220, 152, 135, 495, 145, 225,
#        325, 284, 204, 155, 485, 285, 156, 130, 160, 210, 318, 190, 280,
#        271, 129, 478, 744, 370, 194, 680, 402, 258, 375, 150, 278, 545,
#        182, 360, 215, 184, 132, 148, 180, 205, 231, 255, 171, 167, 249,
#        293, 465, 158, 196, 415, 275, 165, 579, 310, 474, 170, 277, 237,
#        191, 328, 250, 480, 265, 193, 326, 188, 166, 274, 126, 330, 600,
#        185, 272, 321, 144, 183, 440, 159, 540, 200, 335, 387, 291, 392,
#        178, 127, 510], dtype=int64)

# %% [markdown]
# # Q5. Calculate the high rate of glucose & insulin

# %%
dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
BI=dataset.loc[(dataset["Glucose"]>120) & (dataset["Insulin"]>126)]
BI
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 4              0      137             40             35      168  43.1
# 8              2      197             70             45      543  30.5
# 13             1      189             60             23      846  30.1
# 14             5      166             72             19      175  25.8
# 20             3      126             88             41      235  39.3
# ..           ...      ...            ...            ...      ...   ...
# 716            3      173             78             39      185  33.8
# 722            1      149             68             29      127  29.3
# 744           13      153             88             37      140  40.6
# 748            3      187             70             22      200  36.4
# 753            0      181             88             44      510  43.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 4                       2.288   33        1
# ...

# %%
n=BI[["Glucose","Insulin"]]
n
# Out:
#      Glucose  Insulin
# 4        137      168
# 8        197      543
# 13       189      846
# 14       166      175
# 20       126      235
# ..       ...      ...
# 716      173      185
# 722      149      127
# 744      153      140
# 748      187      200
# 753      181      510
#
# [144 rows x 2 columns]

# %%
n.max()
# Out:
# Glucose    198
# Insulin    846
# dtype: int64
