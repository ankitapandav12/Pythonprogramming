# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv(r"C:\Users\Sushant\Desktop\Ankita\Datasets\CarPrice.csv")
dataset
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
data=dataset[["CarName","fueltype","carlength","carwidth","carheight","price"]]
data
# Out:
#                       CarName fueltype  carlength  carwidth  carheight  \
# 0          alfa-romero giulia      gas      168.8      64.1       48.8
# 1         alfa-romero stelvio      gas      168.8      64.1       48.8
# 2    alfa-romero Quadrifoglio      gas      171.2      65.5       52.4
# 3                 audi 100 ls      gas      176.6      66.2       54.3
# 4                  audi 100ls      gas      176.6      66.4       54.3
# ..                        ...      ...        ...       ...        ...
# 200           volvo 145e (sw)      gas      188.8      68.9       55.5
# 201               volvo 144ea      gas      188.8      68.8       55.5
# 202               volvo 244dl      gas      188.8      68.9       55.5
# 203                 volvo 246   diesel      188.8      68.9       55.5
# 204               volvo 264gl      gas      188.8      68.9       55.5
#
#        price
# 0    13495.0
# 1    16500.0
# 2    16500.0
# 3    13950.0
# 4    17450.0
# ..       ...
# ...

# %%
data["new"]=np.nan
data
# Out:
# C:\Users\Sushant\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                       CarName fueltype  carlength  carwidth  carheight  \
# 0          alfa-romero giulia      gas      168.8      64.1       48.8
# 1         alfa-romero stelvio      gas      168.8      64.1       48.8
# 2    alfa-romero Quadrifoglio      gas      171.2      65.5       52.4
# 3                 audi 100 ls      gas      176.6      66.2       54.3
# 4                  audi 100ls      gas      176.6      66.4       54.3
# ..                        ...      ...        ...       ...        ...
# ...

# %%
data.insert(1,"index",np.nan)
data
# Out:
#                       CarName  index fueltype  carlength  carwidth  carheight  \
# 0          alfa-romero giulia    NaN      gas      168.8      64.1       48.8
# 1         alfa-romero stelvio    NaN      gas      168.8      64.1       48.8
# 2    alfa-romero Quadrifoglio    NaN      gas      171.2      65.5       52.4
# 3                 audi 100 ls    NaN      gas      176.6      66.2       54.3
# 4                  audi 100ls    NaN      gas      176.6      66.4       54.3
# ..                        ...    ...      ...        ...       ...        ...
# 200           volvo 145e (sw)    NaN      gas      188.8      68.9       55.5
# 201               volvo 144ea    NaN      gas      188.8      68.8       55.5
# 202               volvo 244dl    NaN      gas      188.8      68.9       55.5
# 203                 volvo 246    NaN   diesel      188.8      68.9       55.5
# 204               volvo 264gl    NaN      gas      188.8      68.9       55.5
#
#        price  new
# ...

# %%
data["index"].fillna("xyz",inplace=True)
data
# Out:
# C:\Users\Sushant\anaconda3\lib\site-packages\pandas\core\generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
#                       CarName index fueltype  carlength  carwidth  carheight  \
# 0          alfa-romero giulia   xyz      gas      168.8      64.1       48.8
# 1         alfa-romero stelvio   xyz      gas      168.8      64.1       48.8
# 2    alfa-romero Quadrifoglio   xyz      gas      171.2      65.5       52.4
# 3                 audi 100 ls   xyz      gas      176.6      66.2       54.3
# 4                  audi 100ls   xyz      gas      176.6      66.4       54.3
# ..                        ...   ...      ...        ...       ...        ...
# 200           volvo 145e (sw)   xyz      gas      188.8      68.9       55.5
# ...

# %%
data["fueltype"].replace("gas","air_gas",inplace=True)
data
# Out:
# C:\Users\Sushant\anaconda3\lib\site-packages\pandas\core\generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
#                       CarName index fueltype  carlength  carwidth  carheight  \
# 0          alfa-romero giulia   xyz  air_gas      168.8      64.1       48.8
# 1         alfa-romero stelvio   xyz  air_gas      168.8      64.1       48.8
# 2    alfa-romero Quadrifoglio   xyz  air_gas      171.2      65.5       52.4
# 3                 audi 100 ls   xyz  air_gas      176.6      66.2       54.3
# 4                  audi 100ls   xyz  air_gas      176.6      66.4       54.3
# ..                        ...   ...      ...        ...       ...        ...
# 200           volvo 145e (sw)   xyz  air_gas      188.8      68.9       55.5
# ...

# %%
del data["price"]
data
# Out:
#                       CarName index fueltype  carlength  carwidth  carheight  \
# 0          alfa-romero giulia   xyz  air_gas      168.8      64.1       48.8
# 1         alfa-romero stelvio   xyz  air_gas      168.8      64.1       48.8
# 2    alfa-romero Quadrifoglio   xyz  air_gas      171.2      65.5       52.4
# 3                 audi 100 ls   xyz  air_gas      176.6      66.2       54.3
# 4                  audi 100ls   xyz  air_gas      176.6      66.4       54.3
# ..                        ...   ...      ...        ...       ...        ...
# 200           volvo 145e (sw)   xyz  air_gas      188.8      68.9       55.5
# 201               volvo 144ea   xyz  air_gas      188.8      68.8       55.5
# 202               volvo 244dl   xyz  air_gas      188.8      68.9       55.5
# 203                 volvo 246   xyz   diesel      188.8      68.9       55.5
# 204               volvo 264gl   xyz  air_gas      188.8      68.9       55.5
#
#      new
# 0    NaN
# 1    NaN
# 2    NaN
# ...

# %%
data.rename(columns={"CarName":"cars"})
# Out:
#                          cars index fueltype  carlength  carwidth  carheight  \
# 0          alfa-romero giulia   xyz  air_gas      168.8      64.1       48.8
# 1         alfa-romero stelvio   xyz  air_gas      168.8      64.1       48.8
# 2    alfa-romero Quadrifoglio   xyz  air_gas      171.2      65.5       52.4
# 3                 audi 100 ls   xyz  air_gas      176.6      66.2       54.3
# 4                  audi 100ls   xyz  air_gas      176.6      66.4       54.3
# ..                        ...   ...      ...        ...       ...        ...
# 200           volvo 145e (sw)   xyz  air_gas      188.8      68.9       55.5
# 201               volvo 144ea   xyz  air_gas      188.8      68.8       55.5
# 202               volvo 244dl   xyz  air_gas      188.8      68.9       55.5
# 203                 volvo 246   xyz   diesel      188.8      68.9       55.5
# 204               volvo 264gl   xyz  air_gas      188.8      68.9       55.5
#
#      new
# 0    NaN
# 1    NaN
# 2    NaN
# ...
